# %%
import numpy as np 
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Prepare data

# %%
# Read data
from sklearn.model_selection import train_test_split
data= pd.read_csv('concrete_data.csv')

# Split data
X = data.drop(['Strength'],axis =1)
y = data['Strength']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Build model

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(10, activation = 'relu', input_shape=(X.shape[1],)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# # Train & Validate model

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 23/23 [==============================] - 1s 11ms/step - loss: 337728.3438 - val_loss: 272718.1875
# Epoch 2/50
# 23/23 [==============================] - 0s 4ms/step - loss: 235261.7969 - val_loss: 191025.0156
# Epoch 3/50
# 23/23 [==============================] - 0s 4ms/step - loss: 164067.6250 - val_loss: 129330.1094
# Epoch 4/50
# 23/23 [==============================] - 0s 4ms/step - loss: 105263.3594 - val_loss: 76490.4531
# Epoch 5/50
# 23/23 [==============================] - 0s 3ms/step - loss: 59986.5039 - val_loss: 41291.6836
# Epoch 6/50
# 23/23 [==============================] - 0s 4ms/step - loss: 31651.2090 - val_loss: 20750.8359
# Epoch 7/50
# 23/23 [==============================] - 0s 3ms/step - loss: 15615.1348 - val_loss: 9848.5518
# Epoch 8/50
# 23/23 [==============================] - 0s 3ms/step - loss: 7475.4937 - val_loss: 4922.5562
# Epoch 9/50
# 23/23 [==============================] - 0s 4ms/step - loss: 3940.1130 - val_loss: 3069.8606
# Epoch 10/50
# 23/23 [==============================] - 0s 3ms/step - loss: 2692.6052 - val_loss: 2536.8503
# Epoch 11/50
# 23/23 [==============================] - 0s 3ms/step - loss: 2300.9490 - val_loss: 2413.1255
# Epoch 12/50
# 23/23 [==============================] - 0s 3ms/step - loss: 2185.8413 - val_loss: 2368.9158
# Epoch 13/50
# 23/23 [==============================] - 0s 3ms/step - loss: 2127.0674 - val_loss: 2328.0564
# Epoch 14/50
# 23/23 [==============================] - 0s 3ms/step - loss: 2079.5750 - val_loss: 2283.7158
# Epoch 15/50
# 23/23 [==============================] - 0s 4ms/step - loss: 2035.0925 - val_loss: 2235.0212
# Epoch 16/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1991.9319 - val_loss: 2192.6277
# Epoch 17/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1943.7219 - val_loss: 2137.5527
# Epoch 18/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1898.3976 - val_loss: 2091.3438
# Epoch 19/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1853.0770 - val_loss: 2044.2534
# Epoch 20/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1808.5824 - val_loss: 1995.4181
# Epoch 21/50
# 23/23 [==============================] - 0s 4ms/step - loss: 1765.1748 - val_loss: 1951.2679
# Epoch 22/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1721.3481 - val_loss: 1906.8079
# Epoch 23/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1680.2223 - val_loss: 1858.6299
# Epoch 24/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1637.9996 - val_loss: 1815.4106
# Epoch 25/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1596.6204 - val_loss: 1772.7620
# Epoch 26/50
# 23/23 [==============================] - 0s 4ms/step - loss: 1556.8112 - val_loss: 1726.0305
# Epoch 27/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1518.3064 - val_loss: 1680.2380
# Epoch 28/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1479.3369 - val_loss: 1641.3804
# Epoch 29/50
# 23/23 [==============================] - 0s 5ms/step - loss: 1441.4409 - val_loss: 1603.0958
# Epoch 30/50
# 23/23 [==============================] - 0s 4ms/step - loss: 1405.5197 - val_loss: 1564.5719
# Epoch 31/50
# 23/23 [==============================] - 0s 4ms/step - loss: 1371.6320 - val_loss: 1524.2300
# Epoch 32/50
# 23/23 [==============================] - 0s 4ms/step - loss: 1337.2537 - val_loss: 1488.0991
# Epoch 33/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1305.2274 - val_loss: 1452.3214
# Epoch 34/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1272.1653 - val_loss: 1421.4850
# Epoch 35/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1242.2582 - val_loss: 1386.9119
# Epoch 36/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1211.8987 - val_loss: 1352.2211
# Epoch 37/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1183.3350 - val_loss: 1317.3030
# Epoch 38/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1153.7021 - val_loss: 1290.9005
# Epoch 39/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1126.4031 - val_loss: 1259.1669
# Epoch 40/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1100.0670 - val_loss: 1228.7544
# Epoch 41/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1074.5956 - val_loss: 1204.8134
# Epoch 42/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1048.7135 - val_loss: 1172.8887
# Epoch 43/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1024.2079 - val_loss: 1148.0286
# Epoch 44/50
# 23/23 [==============================] - 0s 3ms/step - loss: 1000.5748 - val_loss: 1121.6289
# Epoch 45/50
# 23/23 [==============================] - 0s 3ms/step - loss: 978.2568 - val_loss: 1097.0887
# Epoch 46/50
# 23/23 [==============================] - 0s 3ms/step - loss: 956.5093 - val_loss: 1069.1315
# Epoch 47/50
# 23/23 [==============================] - 0s 3ms/step - loss: 934.4600 - val_loss: 1048.1600
# Epoch 48/50
# 23/23 [==============================] - 0s 3ms/step - loss: 912.2966 - val_loss: 1022.8146
# Epoch 49/50
# 23/23 [==============================] - 0s 3ms/step - loss: 892.0196 - val_loss: 1002.1669
# Epoch 50/50
# 23/23 [==============================] - 0s 3ms/step - loss: 873.2972 - val_loss: 984.3764

# %% [markdown]
# # Report

# %%
# list of mse on test set
mse_history = model.history.history['val_loss']

# %%
# Calculate mean and standard deviation
print(f'Mean of MSEs: {np.mean(mse_history)}')
print(f'Standard Deviation of MSEs: {np.std(mse_history)}')
# Out:
# Mean of MSEs: 16323.736403808594
# Standard Deviation of MSEs: 49498.06296353532
